# %%
import matplotlib.pyplot as plt
import pyplotbrookings as ppb
import seaborn as sns

# Brookings plot theme for all plots
ppb.set_theme()

# %%
# Setting brand colors for current plot
ppb.set_pallet('brand2', reverse=False)

# Getting data
penguins = sns.load_dataset("penguins")

# Plotting histograms
plt.hist(penguins[penguins['species'] == 'Adelie']['bill_depth_mm'], alpha=0.5, label='Adeline')
plt.hist(penguins[penguins['species'] == 'Chinstrap']['bill_depth_mm'], alpha=0.5, label='Chinstrap')
plt.hist(penguins[penguins['species'] == 'Gentoo']['bill_depth_mm'], alpha=0.5, label='Gentoo')
# Adding matplotlib legend/labels
plt.legend(ncol=3)
plt.xlabel('Bill Depth (mm)')
plt.ylabel('Count')

# Adding Brookings titles and logos
ppb.add_title(title='Penguin Bill Depth', subtitle='Bill Depth in mm of Adelie and Gentoo Penguins at Palmer Station LTER', 
          tag='FIGURE 1', source='Palmer Station Antarctica LTER', notes='Figure made using matplotlib')
ppb.add_logo('hc')

# %%
cmap = ppb.get_cmap('brand blue', reverse=True)
plt.scatter(data=penguins, x='bill_length_mm', y='bill_depth_mm', c='flipper_length_mm', cmap=cmap)

# Adding matplotlib legend/labels
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
# Adding color bar (as far as I can tell the deprecation warning is a bug in matplotlib)
cbar = plt.colorbar(cmap=cmap)
cbar.set_label('Flipper Length (mm)')
cbar.outline.set_visible(False)

# Adding Brookings titles and logos
ppb.add_title(title='Penguin Bills and Flippers', subtitle='Bill length vs. Bill Depth vs. Flipper Length of Penguins at Palmer Station', 
          tag='FIGURE 2', source='Palmer Station Antarctica LTER', notes='Figure made using matplotlib')
ppb.add_logo('crm', scale=0.35, offsets=(-0.1, 0))
# Out:
# /Users/adamsedlak/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
